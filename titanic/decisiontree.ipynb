# %% [markdown]
# # Topgun titanic and decision trees

# %% [markdown]
# [Init Source](https://www.w3schools.com/python/python_ml_decision_tree.asp)

# %% [markdown]
# data available: PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# features: Pclass,Sex,Age,SibSp,Parch,Fare

# %%
import pandas
from sklearn import tree
import pydotplus
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

df = pandas.read_csv("train.csv").dropna()
d = {'female': 0, 'male': 1}
df['Sex'] = df['Sex'].map(d)

features = ['Sex', 'Age', 'SibSp', 'Parch', 'Fare']

X = df[features]
y = df['Survived']

print(X, y)
# Out:
#      Sex   Age  SibSp  Parch     Fare
# 1      0  38.0      1      0  71.2833
# 3      0  35.0      1      0  53.1000
# 6      1  54.0      0      0  51.8625
# 10     0   4.0      1      1  16.7000
# 11     0  58.0      0      0  26.5500
# ..   ...   ...    ...    ...      ...
# 871    0  47.0      1      1  52.5542
# 872    1  33.0      0      0   5.0000
# 879    0  56.0      0      1  83.1583
# 887    0  19.0      0      0  30.0000
# 889    1  26.0      0      0  30.0000
#
# [183 rows x 5 columns] 1      1
# 3      1
# 6      0
# 10     1
# 11     1
#       ..
# 871    1
# 872    0
# 879    1
# 887    1
# 889    1
# Name: Survived, Length: 183, dtype: int64

# %%
dtree = DecisionTreeClassifier(max_depth=5)
dtree = dtree.fit(X, y)
data = tree.export_graphviz(dtree, out_file=None, feature_names=features)
graph = pydotplus.graph_from_dot_data(data)
graph.write_png('mydecisiontree.png')

img=pltimg.imread('mydecisiontree.png')
imgplot = plt.imshow(img)
plt.show()
